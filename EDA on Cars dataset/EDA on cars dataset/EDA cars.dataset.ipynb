# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Car_dataset.csv')

# %%
df
# Out:
#       Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0              0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1              1   2899       ford       se  2011  clean vehicle  190552.0
# 2              2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3              3  25000       ford     door  2014  clean vehicle   64146.0
# 4              4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# ...          ...    ...        ...      ...   ...            ...       ...
# 2494        2494   7800     nissan    versa  2019  clean vehicle   23609.0
# 2495        2495   9200     nissan    versa  2018  clean vehicle   34553.0
# 2496        2496   9200     nissan    versa  2018  clean vehicle   31594.0
# 2497        2497   9200     nissan    versa  2018  clean vehicle   32557.0
# 2498        2498   9200     nissan    versa  2018  clean vehicle   31371.0
#
#        color                  vin        lot       state country  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
   df.tail(10)
# Out:
#       Unnamed: 0  price   brand   model  year   title_status  mileage   color  \
# 2489        2489  13900  nissan   rogue  2018  clean vehicle  40259.0    gray
# 2490        2490  10400  nissan  sentra  2019  clean vehicle  25264.0    blue
# 2491        2491   9200  nissan   versa  2018  clean vehicle  35677.0   black
# 2492        2492   7400  nissan   versa  2019  clean vehicle  35511.0   black
# 2493        2493   9200  nissan   versa  2018  clean vehicle  33027.0   black
# 2494        2494   7800  nissan   versa  2019  clean vehicle  23609.0     red
# 2495        2495   9200  nissan   versa  2018  clean vehicle  34553.0  silver
# 2496        2496   9200  nissan   versa  2018  clean vehicle  31594.0  silver
# 2497        2497   9200  nissan   versa  2018  clean vehicle  32557.0   black
# 2498        2498   9200  nissan   versa  2018  clean vehicle  31371.0  silver
#
#                       vin        lot       state country      condition
# ...

# %%
#to select a column df['name']
df['model']
# Out:
# 0       cruiser
# 1            se
# 2           mpv
# 3          door
# 4          1500
#          ...
# 2494      versa
# 2495      versa
# 2496      versa
# 2497      versa
# 2498      versa
# Name: model, Length: 2499, dtype: object

# %%
df['color'].value_counts()
# Out:
# color
# white                                      707
# black                                      516
# gray                                       395
# silver                                     300
# red                                        192
# blue                                       151
# no_color                                    61
# green                                       24
# orange                                      20
# gold                                        19
# charcoal                                    18
# brown                                       15
# yellow                                       9
# magnetic metallic                            6
# shadow black                                 5
# color:                                       5
# beige                                        5
# oxford white                                 4
# ingot silver metallic                        4
# super black                                  3
# ...

# %% [markdown]
# #KDE plot used for visualizing

# %%
sns.kdeplot(data=df['price'],label="Price")
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
#histogram
df['price'].hist()
# Out:
# <Axes: >

# %%
df['brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='brand'>

# %%
df['color'].value_counts().plot(kind='barh',figsize=[20,10])
# Out:
# <Axes: ylabel='color'>

# %%
 max(df['price'])
# Out:
# 84900

# %%
df['brand'][df['price'] ==max(df['price'])]
# Out:
# 502    mercedes-benz
# Name: brand, dtype: object

# %%
price_df = df.groupby('brand')['price'].max().reset_index()

# %%
price_df
# Out:
#               brand  price
# 0             acura  16900
# 1              audi  36400
# 2               bmw  61200
# 3             buick  37500
# 4          cadillac  47500
# 5         chevrolet  63200
# 6          chrysler  29100
# 7             dodge  67000
# 8              ford  74000
# 9               gmc  48500
# 10  harley-davidson  54680
# 11        heartland   6680
# 12            honda  17200
# 13          hyundai   9800
# 14         infiniti  18500
# 15           jaguar   2800
# 16             jeep  21100
# 17              kia  21500
# 18             land  46900
# 19            lexus  55600
# 20          lincoln  36300
# 21         maserati  30300
# 22            mazda  16000
# 23    mercedes-benz  84900
# 24           nissan  36300
# 25        peterbilt   1025
# 26              ram  11050
# 27           toyota   6300

# %%
price_df_new=price_df.set_index('brand')
price_df_new
# Out:
#                  price
# brand
# acura            16900
# audi             36400
# bmw              61200
# buick            37500
# cadillac         47500
# chevrolet        63200
# chrysler         29100
# dodge            67000
# ford             74000
# gmc              48500
# harley-davidson  54680
# heartland         6680
# honda            17200
# hyundai           9800
# infiniti         18500
# jaguar            2800
# jeep             21100
# kia              21500
# land             46900
# lexus            55600
# lincoln          36300
# maserati         30300
# mazda            16000
# mercedes-benz    84900
# nissan           36300
# peterbilt         1025
# ram              11050
# toyota            6300

# %%
price_df_new.plot(kind='pie',y='price')
# Out:
# <Axes: ylabel='price'>
